# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np



# Load the audio file
audio_file = 'ball_bounce_brick_mono.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the audio file
audio_file = 'ball_bounce_brick_stereo.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the audio file
audio_file = 'ball_bounce_paddle_mono.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the audio file
audio_file = 'ball_bounce_paddle_stereo.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the audio file
audio_file = 'paddle_widening_mono.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Load the audio file
audio_file = 'paddle_widening_stereo.wav'
y, sr = librosa.load(audio_file)

# Compute the Short-Time Fourier Transform (STFT) of the audio signal
D = librosa.stft(y)

# Convert the STFT to a magnitude spectrogram
mag = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Plot the spectrogram
librosa.display.specshow(mag, sr=sr, y_axis='linear', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()
